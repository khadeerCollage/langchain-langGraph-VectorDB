# %% [markdown]
# # Rag application using type sense

# %%
import typesense

# %%
client = typesense.Client({
    'nodes': [{
        'host': 'f6oula7wryej1qcgp-1.a1.typesense.net',
        'port': '443',
        'protocol': 'https'
    }],
    'api_key':'oTIk8vjSk9lwMAGLx3lmOrVWePvDh8PV',
    'connection_timeout_seconds': 2
    
})
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.

# %% [markdown]
# # if we have the typesenseclinet with to search fast...

# %%
# we have the book schema 

schema = {
    'name': 'books',
    'fields': [
        {'name': 'id', 'type': 'string'},
        {'name': 'title', 'type': 'string'},
        {'name': 'authors', 'type': 'string[]', 'facet': True},
        {'name': 'publication_year', 'type': 'int32', 'facet': True}
    ]
}

# %%
with open ('books.jsonl','r') as f:
    data  = f.read()
    client.collections['books'].documents.import_(data)

# %%
search_parameters = {
    'q': 'history',
    'query_by': 'title,authors',
    'filter_by': 'publication_year:>2000',
    'sort_by': 'publication_year:desc'
}
results = client.collections['books'].documents.search(search_parameters)
print(results)

# %% [markdown]
# # langchain + open ai llm + typesense + rag application

# %%
from langchain_openai import OpenAI
from langchain_community.vectorstores import Typesense
from langchain_text_splitters import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 4
#       2 from langchain_community.vectorstores import Typesense
#       3 from langchain_text_splitters import CharacterTextSplitter
# ----> 4 from langchain.embeddings import HuggingFaceEmbeddings
#       5 from langchain_community.document_loaders import TextLoader
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'langchain.embeddings' (c:\Users\USER\Desktop\pinecone-demo\.venv\Lib\site-packages\langchain\embeddings\__init__.py)

# %%
import os 
os.environ['openai_api_key'] = 'OPENAI_API_KEY=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'

# %%
loader = TextLoader('doc2.txt')
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = HuggingFaceEmbeddings()
